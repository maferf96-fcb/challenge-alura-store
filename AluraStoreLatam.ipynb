# %% [markdown]
# # **Biblioteca de datos**
#
# Estructura de datos:
# El conjunto de datos incluye la siguiente información:
#
# Producto y Categoría: Artículos vendidos y sus calificaciones.
#
# Precio y Envío: Valores de venta y costos asociados.
#
# Fecha y ubicación de compra: Información temporal y geográfica.
#
# Evaluación de compra: Comentarios de clientes.
#
# Tipo de Pago y Cuotas: Métodos utilizados por los clientes.
#
# Coordenadas Geográficas: Ubicación de las transacciones.

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda.shape
# Out:
# (2359, 12)

# %%
tienda.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %%
tienda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ### Ingreso total por cada tienda
# En este primer análisis se calcula el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %%
total_tienda = tienda['Precio'].sum()
total_tienda
# Out:
# np.float64(1150880400.0)

# %%
total_tienda2 = tienda2['Precio'].sum()
total_tienda2
# Out:
# np.float64(1116343500.0)

# %%
total_tienda3 = tienda3['Precio'].sum()
total_tienda3
# Out:
# np.float64(1098019600.0)

# %%
total_tienda4 = tienda4['Precio'].sum()
total_tienda4
# Out:
# np.float64(1038375700.0)

# %%
print(f" el valor total de la tienda es {total_tienda}")
print(f" el valor total de la tienda2 es {total_tienda2}")
print(f" el valor total de la tienda3 es {total_tienda3}")
print(f" el valor total de la tienda4 es {total_tienda4}")
# Out:
#  el valor total de la tienda es 1150880400.0
#  el valor total de la tienda2 es 1116343500.0
#  el valor total de la tienda3 es 1098019600.0
#  el valor total de la tienda4 es 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría
#
# Se calcula la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
tienda.groupby('Categoría del Producto').mean(numeric_only=True)
# Out:
#                                Precio  Costo de envío  Calificación  \
# Categoría del Producto
# Artículos para el hogar  7.425965e+04     3764.912281      3.748538
# Deportes y diversión     1.383451e+05     7468.661972      3.897887
# Electrodomésticos        1.165658e+06    61935.897436      4.032051
# Electrónicos             9.586908e+05    51258.258929      4.004464
# Instrumentos musicales   5.016429e+05    26834.615385      4.049451
# Juguetes                 5.554228e+04     3023.148148      4.077160
# Libros                   5.077977e+04     2699.421965      3.976879
# Muebles                  4.035133e+05    21494.408602      3.946237
#
#                          Cantidad de cuotas       lat        lon
# Categoría del Producto
# Artículos para el hogar            2.859649  5.668980 -74.760683
# Deportes y diversión               2.802817  5.189375 -74.813845
# Electrodomésticos                  2.903846  5.154013 -74.755243
# ...

# %%
cant_tienda = tienda["Categoría del Producto"].value_counts().rename("Cantidad de productos vendidos")
cant_tienda
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: Cantidad de productos vendidos, dtype: int64

# %%
cant_tienda2 = tienda2["Categoría del Producto"].value_counts().rename("Cantidad de productos vendidos")
cant_tienda2
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: Cantidad de productos vendidos, dtype: int64

# %%
cant_tienda3 = tienda3["Categoría del Producto"].value_counts().rename("Cantidad de productos vendidos")
cant_tienda3
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: Cantidad de productos vendidos, dtype: int64

# %%
cant_tienda4 = tienda4["Categoría del Producto"].value_counts().rename("Cantidad de productos vendidos")
cant_tienda4
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: Cantidad de productos vendidos, dtype: int64

# %%
ventas_por_categoria = tienda.groupby("Categoría del Producto")[["Precio"]].sum().sort_values("Precio", ascending=False)
ventas_por_categoria2 = tienda2.groupby("Categoría del Producto")[["Precio"]].sum().sort_values("Precio", ascending=False)
ventas_por_categoria3 = tienda3.groupby("Categoría del Producto")[["Precio"]].sum().sort_values("Precio", ascending=False)
ventas_por_categoria4 = tienda4.groupby("Categoría del Producto")[["Precio"]].sum().sort_values("Precio", ascending=False)

print(f" Tienda 1 Precio {ventas_por_categoria}")
print(f" Tienda 2 Precio {ventas_por_categoria2}")
print(f" Tienda 3 Precio {ventas_por_categoria3}")
print(f" Tienda 4 Precio {ventas_por_categoria4}")
# Out:
#  Tienda 1 Precio                               Precio
# Categoría del Producto
# Electrónicos             429493500.0
# Electrodomésticos        363685200.0
# Muebles                  187633700.0
# Instrumentos musicales    91299000.0
# Deportes y diversión      39290000.0
# Juguetes                  17995700.0
# Artículos para el hogar   12698400.0
# Libros                     8784900.0
#  Tienda 2 Precio                               Precio
# Categoría del Producto
# Electrónicos             410831100.0
# Electrodomésticos        348567800.0
# Muebles                  176426300.0
# Instrumentos musicales   104990300.0
# Deportes y diversión      34744500.0
# Juguetes                  15945400.0
# Artículos para el hogar   14746900.0
# Libros                    10091200.0
#  Tienda 3 Precio                               Precio
# Categoría del Producto
# Electrónicos             410775800.0
# Electrodomésticos        329237900.0
# Muebles                  201072100.0
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda
#
# En este paso, se calculan las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %%
calificacion_prom_tienda = tienda["Calificación"].mean()
print(f"La calificación promedio es de {round(calificacion_prom_tienda,2)} para la tienda")
# Out:
# La calificación promedio es de 3.98 para la tienda

# %%
calificacion_prom_tienda2 = tienda2["Calificación"].mean()
print(f"La calificación promedio es de {round(calificacion_prom_tienda2,2)} para la tienda")
# Out:
# La calificación promedio es de 4.04 para la tienda

# %%
calificacion_prom_tienda3 = tienda3["Calificación"].mean()
print(f"La calificación promedio es de {round(calificacion_prom_tienda3,2)} para la tienda")
# Out:
# La calificación promedio es de 4.05 para la tienda

# %%
calificacion_prom_tienda4 = tienda4["Calificación"].mean()
print(f"La calificación promedio es de {round(calificacion_prom_tienda4,2)} para la tienda")
# Out:
# La calificación promedio es de 4.0 para la tienda

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
def Productos_mas_menos_vendidos(data):
    # Agrupar por producto y sumar las facturaciones
    ventas_por_producto = data.groupby('Producto')['Precio'].sum().sort_values(ascending=False)

    # Obtener el producto con mayor facturación
    producto_mas_vendido = ventas_por_producto.idxmax(), ventas_por_producto.max()

    # Obtener el producto con menor facturación
    producto_menos_vendido = ventas_por_producto.idxmin(), ventas_por_producto.min()

    return producto_mas_vendido, producto_menos_vendido

# %%
mas_menos_tienda = Productos_mas_menos_vendidos(tienda)
mas_menos_tienda2 = Productos_mas_menos_vendidos(tienda2)
mas_menos_tienda3 = Productos_mas_menos_vendidos(tienda3)
mas_menos_tienda4 = Productos_mas_menos_vendidos(tienda4)

# %%
mas_menos_tienda
# Out:
# (('TV LED UHD 4K', 142150200.0), ('Cuerda para saltar', 652800.0))

# %%
mas_menos_tienda2
# Out:
# (('Iphone 15', 113225800.0), ('Cubo mágico 8x8', 643600.0))

# %%
mas_menos_tienda3
# Out:
# (('Refrigerador', 99889700.0), ('Cubo mágico 8x8', 640400.0))

# %%
mas_menos_tienda4
# Out:
# (('Iphone 15', 96697500.0), ('Cuerda para saltar', 704800.0))

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
# Tienda 1

prom_env=round(tienda['Costo de envío'].mean(),2)
print(f"El costo promedio de envio es de {prom_env}")
# Out:
# El costo promedio de envio es de 26018.61

# %%
# Tienda 2

prom_env2=round(tienda2['Costo de envío'].mean(),2)
print(f"El costo promedio de envio es de {prom_env2}")
# Out:
# El costo promedio de envio es de 25216.24

# %%
# Tienda 3

prom_env3=round(tienda3['Costo de envío'].mean(),2)
print(f"El costo promedio de envio es de {prom_env3}")
# Out:
# El costo promedio de envio es de 24805.68

# %%
# Tienda 4

prom_env4=round(tienda4['Costo de envío'].mean(),2)
print(f"El costo promedio de envio es de {prom_env4}")
# Out:
# El costo promedio de envio es de 23459.46

# %% [markdown]
# # 6. Graficos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tiendas= ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
ingresos = [total_tienda, total_tienda2, total_tienda3, total_tienda4]
plt.bar(tiendas, ingresos, color="skyblue")
plt.title("Ingresos por tienda", fontweight="bold", fontsize= 18)
plt.ylabel("Ingresos")
plt.show()

# %%
#Calificacion por tienda

calificaciones = [calificacion_prom_tienda, calificacion_prom_tienda2, calificacion_prom_tienda3, calificacion_prom_tienda4]
plt.plot(tiendas, calificaciones, "o")
plt.title("Nivel de satisfacción de los clientes por tienda", fontweight= "bold", fontsize= 12)
plt.show()

# %%
#costos por envio

costes_send= [prom_env, prom_env2, prom_env3, prom_env4]
plt.scatter(tiendas, costes_send, color="purple")
plt.title("Costos promedio de envío", fontweight= "bold", fontsize= 14)
plt.grid(True, linestyle=":", color="black")

# %% [markdown]
# # 7. Análisis del desempeño geográfico

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_global = pd.concat([tienda, tienda2, tienda3, tienda4], ignore_index=True)

plt.figure(figsize=(12, 8))
scatter = plt.scatter(df_global['lon'], df_global['lat'],
                      c=df_global['Calificación'],
                      cmap='RdYlGn',
                      alpha=0.6,
                      s=50)

plt.colorbar(scatter, label='Calificación del Cliente')
plt.title('Distribución Geográfica de Ventas y Satisfacción', fontsize=15)
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True, alpha=0.2)
plt.show()

# %% [markdown]
# # 8. Informe Final

# %% [markdown]
# 📊 Informe Ejecutivo – Decisión de Cierre/Venta de Tienda
#
# Objetivo: Seleccionar una tienda para vender/cerrar y financiar un nuevo emprendimiento del Sr. Juan.
# Decisión solicitada: Elegir una tienda para cerrar.
#
# 🔍 Resumen de los indicadores clave
# 💰 Ingresos Totales
#
# Tienda 1: 1,212,258,300 (más alta)
#
# Tienda 2: 1,175,828,600
#
# Tienda 3: 1,156,536,200
#
# Tienda 4: 1,093,693,100 (más baja)
#
# ➡️ La Tienda 4 es la que menos ingresos genera.
#
# ⭐ Satisfacción del Cliente (Rating)
#
# Tienda 1: 3.98 ⭐ (más baja)
#
# Tienda 2: 4.04 ⭐
#
# Tienda 3: 4.05 ⭐ (mejor calificada)
#
# Tienda 4: 4.00 ⭐
#
# ➡️ Las diferencias son mínimas, ninguna tienda está en crisis por rating.
#
# 🚚 Costos de Envío (Promedio)
#
# Tienda 1: 26,018.61 (más alto)
#
# Tienda 2: 25,216.24
#
# Tienda 3: 24,805.68
#
# Tienda 4: 23,459.46 (más bajo)
#
# ➡️ La Tienda 4 es la más eficiente en logística, pero no logra convertir eso en mayores ventas.
#
# 🛒 Desempeño Comercial de Tienda 4
#
# Fortalezas:
#
# Producto estrella: Cama box
#
# Costos de envío más bajos
#
# Buen rating (4.0)
#
# Debilidades:
#
# Menores ingresos del grupo
#
# Categorías con bajo desempeño
#
# Menor volumen de ventas
#
# Dependencia de pocos productos
#
# Menor impacto en el ecosistema general de la empresa
#
# 🔴 Se recomienda cerrar/vender la Tienda 4
#
# Justificación:
#
# Es la tienda con menores ingresos totales.
#
# Aporta menos al resultado global del negocio.
#
# Aunque tiene buena logística, no logra compensar su bajo rendimiento comercial.
#
# Cerrar la Tienda 4 genera menor impacto negativo en la operación total de Alura Store.
#
# 👉 Mantener Tienda 1, 2 y 3 permite conservar:
#
# Mayor facturación
#
# Mejor posicionamiento de marca
#
# Mayor volumen de ventas
#
# Mejor potencial de crecimiento
#
# 🎯 Recomendación Estratégica Post-Cierre
#
# Si se vende/cierra la Tienda 4, se sugiere:
#
# 📈 Reforzar inventario en Tienda 1 y 3
#
# 🚀 Replicar la eficiencia logística de Tienda 4 en las otras tiendas
#
# 🎯 Invertir el capital en:
#
# Marketing
#
# Reducción de costos logísticos
#
# Expansión del nuevo emprendimiento del Sr. Juan
#
# ✍️ Conclusión Ejecutiva (para entregar al profe o jefe)
#
# Con base en el análisis de ingresos, calificaciones, ventas por categoría, desempeño de productos y costos logísticos, se concluye que la Tienda 4 es la opción más conveniente para cerrar o vender, ya que presenta el menor rendimiento financiero general y el menor impacto estratégico dentro del ecosistema de Alura Store, pese a su eficiencia en costos de envío. Cerrar esta tienda permite liberar recursos sin comprometer de forma significativa la rentabilidad ni la satisfacción global de los clientes.
